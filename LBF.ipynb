# %% [markdown]
# # LBF

# %%
# !pip install lbforaging
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 7.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/951.1 kB ? eta -:--:--
#    ---------------------------------------- 951.1/951.1 kB 15.6 MB/s  0:00:00
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/12.8 MB 11.0 MB/s eta 0:00:02
#    -------------- ------------------------- 4.7/12.8 MB 12.4 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.8 MB 13.1 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.8 MB 13.4 MB/s eta 0:00:01
# ...

# %%
import lbforaging
import gymnasium as gym
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import lbforaging
#       2 import gymnasium as gym
#
# ModuleNotFoundError: No module named 'lbforaging'

# %%
env = gym.make("Foraging-8x8-2p-1f-v3") #coop if cooperative environment

# %%
env.action_space
# Out:
# Tuple(Discrete(6), Discrete(6))

# %%
env.observation_space
# Out:
# Tuple(Box([-1. -1.  0. -1. -1.  0. -1. -1.  0.], [7. 7. 4. 7. 7. 2. 7. 7. 2.], (9,), float32), Box([-1. -1.  0. -1. -1.  0. -1. -1.  0.], [7. 7. 4. 7. 7. 2. 7. 7. 2.], (9,), float32))
